# %% [markdown]
# # Explore the Governance Data Set
#
# This notebook explores the Governence documents data set. We experiment with extraction from various forms of input document, word clouds to get a sense of word frequency and of course machine learning algorithms.

# %% [markdown]
# * Import Corné's python script
# * GM0007CA01.zip contains a link instead of the text
# * invetigate empty files that do have text in the source
# * investigate oddly short files

# %% [markdown]
# ---
# ## Installation and Dependencies
# Here we install dependencies.
#
# For text extraction from the Word documents we use [Antiword](https://pypi.org/project/antiword/), a text extraction front-end to Libreoffice. Your Notebook server should have [Libreoffice](https://www.libreoffice.org/) installed.

# %%
# !pip install pymupdf filetype textract antiword wordcloud beautifulsoup4 unidecode
# Out:
# Requirement already satisfied: pymupdf in /opt/conda/lib/python3.10/site-packages (1.22.3)
# Requirement already satisfied: filetype in /opt/conda/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: textract in /opt/conda/lib/python3.10/site-packages (1.6.5)
# Requirement already satisfied: antiword in /opt/conda/lib/python3.10/site-packages (0.1.0)
# Requirement already satisfied: wordcloud in /opt/conda/lib/python3.10/site-packages (1.9.2)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (4.8.2)
# Requirement already satisfied: unidecode in /opt/conda/lib/python3.10/site-packages (1.3.6)
# Requirement already satisfied: docx2txt~=0.8 in /opt/conda/lib/python3.10/site-packages (from textract) (0.8)
# Requirement already satisfied: extract-msg<=0.29.* in /opt/conda/lib/python3.10/site-packages (from textract) (0.28.7)
# Requirement already satisfied: six~=1.12.0 in /opt/conda/lib/python3.10/site-packages (from textract) (1.12.0)
# Requirement already satisfied: xlrd~=1.2.0 in /opt/conda/lib/python3.10/site-packages (from textract) (1.2.0)
# Requirement already satisfied: pdfminer.six==20191110 in /opt/conda/lib/python3.10/site-packages (from textract) (20191110)
# Requirement already satisfied: chardet==3.* in /opt/conda/lib/python3.10/site-packages (from textract) (3.0.4)
# Requirement already satisfied: argcomplete~=1.10.0 in /opt/conda/lib/python3.10/site-packages (from textract) (1.10.3)
# Requirement already satisfied: python-pptx~=0.6.18 in /opt/conda/lib/python3.10/site-packages (from textract) (0.6.21)
# Requirement already satisfied: SpeechRecognition~=3.8.1 in /opt/conda/lib/python3.10/site-packages (from textract) (3.8.1)
# Requirement already satisfied: sortedcontainers in /opt/conda/lib/python3.10/site-packages (from pdfminer.six==20191110->textract) (2.4.0)
# Requirement already satisfied: pycryptodome in /opt/conda/lib/python3.10/site-packages (from pdfminer.six==20191110->textract) (3.17)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.10/site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: tzlocal>=2.1 in /opt/conda/lib/python3.10/site-packages (from extract-msg<=0.29.*->textract) (5.0.1)
# Requirement already satisfied: olefile>=0.46 in /opt/conda/lib/python3.10/site-packages (from extract-msg<=0.29.*->textract) (0.46)
# Requirement already satisfied: ebcdic>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from extract-msg<=0.29.*->textract) (1.1.1)
# Requirement already satisfied: imapclient==2.1.0 in /opt/conda/lib/python3.10/site-packages (from extract-msg<=0.29.*->textract) (2.1.0)
# Requirement already satisfied: compressed-rtf>=1.0.6 in /opt/conda/lib/python3.10/site-packages (from extract-msg<=0.29.*->textract) (1.0.6)
# Requirement already satisfied: lxml>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from python-pptx~=0.6.18->textract) (4.9.2)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /opt/conda/lib/python3.10/site-packages (from python-pptx~=0.6.18->textract) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.39.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->wordcloud) (23.0)

# %%
import re
import sys
import hashlib
from pathlib import Path
WRITE='w'
READ_BINARY='rb'
import multiprocessing
from multiprocessing import Pool
from collections import Counter
print("python=={}".format(re.sub(r'\s.*', '', sys.version)))

import fitz
from fitz import VersionFitz as fitz__version__
print(f"pymupdf=={fitz__version__}")

import filetype
print(f"filetype=={filetype.__version__}")

import textract
from textract import VERSION as textract__version__
print(f"textract=={textract__version__}")

from wordcloud import WordCloud
from wordcloud import __version__ as wordcloud__version__
print(f"wordcloud=={wordcloud__version__}")

import matplotlib.pyplot as plt
from matplotlib import __version__ as matplotlib__version__
print(f"matplotlib=={matplotlib__version__}")

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
print(f"nltk=={nltk.__version__}")

from bs4 import BeautifulSoup
from bs4 import __version__ as bs4__version__
print(f"beautifulsoup4=={bs4__version__}")

import chardet
print(f"chardet=={chardet.__version__}")

import pandas as pd
print(f"pandas=={pd.__version__}")

from unidecode import unidecode
# Out:
# python==3.10.9
# pymupdf==1.22.0
# filetype==1.2.0
# textract==1.6.5
# wordcloud==1.9.2
# matplotlib==3.7.1
# nltk==3.8.1
# beautifulsoup4==4.8.2
# chardet==3.0.4
# pandas==2.0.1

# %% [markdown]
# ---
# ## Structure of the Data
# As this is a project with unstructured data, we should preserve what little structure there is. The raw data comes as hand written documents from many authors, though the file names are meaningful. This section documents the data structure that we use on disk in this project and defines Python constants and a few [file name globs](https://realpython.com/get-all-files-in-directory-python/#using-a-python-glob-pattern-for-conditional-listing) to make document handling easier.
#
# ### Directory Structure
# The raw data set is *not* in GIT, simply because of the file size. You can ask the project team for the original data set. The raw data files are stored in `executing-enexis/data/Governance/GM*.*` (known as `GLOB_RAW_DOCUMENTS` in Python code). Extracted text and document artifacts can be found under `executing-enexis/cache/Governance/` (`DATA_DIR` in Python).
#
# ### File Name Structure
# The file names to the documents are fixed-length records with the following meaning: `"GM"<gemeente code (4-positions)><document type (2 positions)><id number (2 positions>"."<extension>`.
#
# The gemeente code can be mapped with the codes in `XXX`.
#
# The two-character document type can be found in the table below. Each document type has a glob for quick access to all documents of that type. These globs can be found in the same table, although you may find the mapping intuitive.
#
# | Document Type ID | Document Type             | Pathlib Glob   |
# |------------------|---------------------------|----------------
# | CA               | Coalitieakkoord           | `GLOB_CA`      |
# | DV               | Duurzaamheidsprogramma    | `GLOB_DV`      |
# | EX               | Externe documenten        | `GLOB_EX`      |
# | IK               | Inkoopbeleid              | `GLOB_IK`      |
# | JS               | Jaarstukken               | `GLOB_JS`      |
# | OB               | Overige beleidsdocumenten | `GLOB_OB`      |
# | PB               | Programmabegroting        | `GLOB_PB`      |
# | TV               | Toekomstvise              | `GLOB_TV`      |
# | WS               | Website gemeente          | `GLOB_WS`      |
#
# The file extension is not completely reliable. Especially documents with extension `.zip` seem not to be of mime type `application/zip`, but rather of type `text/html`. More on that in the text extraction, below.

# %%
# take any path and map it from the data directory to the cache directory.
def to_cache(path):
    return Path(str(path).replace('/data/', '/cache/'))

DATA_DIR = '../data/Governance'
CACHE_DIR = '../cache/Governance'
Path(CACHE_DIR).mkdir(parents=True, exist_ok=True)

# The raw documents, warts and all; PDFs, ZIP files and Word documents.
GLOB_RAW_DOCUMENTS = DATA_DIR + '/GM????????.*'

# The files containing the extracted text from the raw documents.
GLOB_ALL_DOCUMENTS = CACHE_DIR + '/GM????????.txt'

GLOB_CA = CACHE_DIR + '/GM????CA??.txt'
GLOB_DV = CACHE_DIR + '/GM????DV??.txt'
GLOB_EX = CACHE_DIR + '/GM????EX??.txt'
GLOB_IK = CACHE_DIR + '/GM????IK??.txt'
GLOB_JS = CACHE_DIR + '/GM????JS??.txt'
GLOB_OB = CACHE_DIR + '/GM????OB??.txt'
GLOB_PB = CACHE_DIR + '/GM????PB??.txt'
GLOB_TV = CACHE_DIR + '/GM????TV??.txt'
GLOB_WS = CACHE_DIR + '/GM????WS??.txt'

# take a glob and make it iterable. We cannot use globs as objects, since these get
# "exhausted" when you iterate over them.
# https://stackoverflow.com/questions/51108256/how-to-take-a-pathname-string-with-wildcards-and-resolve-the-glob-with-pathlib
def expand_glob(glob):
    p = Path(glob)
    return Path(p.parent).expanduser().glob(p.name)

print(f"raw documents: {GLOB_RAW_DOCUMENTS}")
print(f"extracted documents = {GLOB_ALL_DOCUMENTS}")
# Out:
# raw documents: ../data/Governance/GM????????.*
# extracted documents = ../cache/Governance/GM????????.txt

# %% [markdown]
# ---
# ## Text Extraction
# This section extracts the text from the raw documents. It deals with the file formats and file encodings. Text extraction from Word files is done with Antiword and Libreoffice. For the PDFs we use [PyMuPDF](https://pypi.org/project/PyMuPDF/) instead. Antiword's development seems to have stagnated, so we only use it where we have to. HTML is cleaned up using [Beautiful Soup](https://pypi.org/project/beautifulsoup4/).
#
# As usual there are a few document oddities to contend with: a mix of file encodings, some documents are empty and some have the wrong [MIME type](https://en.wikipedia.org/wiki/Media_type#Mime.types). For example, documents with extension `.zip` seem not to be of MIME type `application/zip`, but rather of type `text/html`. Some of these `.zip` files are empty as well. There is one text document that contains CSS, so we exclude that specific file.
#
# For tokenization we chose quite a limited set of acceptable characters: only alphabetic characters and a few [accented characters](https://nl.wikipedia.org/wiki/Accenttekens_in_de_Nederlandse_spelling) that are common in the Dutch language. Early experiments showed that a lot of numerical "words" would creep into the data. That makes sense as many of these documents talk about finance, but hinders finding meaning. Numbers really only make sense in context and we simply don't have the context. By stripping out the numbers we also stripped the years out of the text, which do have meaning out of context. We chose to leave these out.
#
# The text extraction also performs some light preprocessing on the text, such as [stop word removal](https://en.wikipedia.org/wiki/Stop_word) and [stemming](https://en.wikipedia.org/wiki/Stemming), taking care to use the Dutch form of each of these. These are fairly slow operations, so they combine well with the extract-and-cache step of the process. That said, we should not preprocess too much, lest we subtly change the meaning of the text.
#
# Due to the nature, number and size of the raw documents, text extraction takes quite a bit of time. To speed up iterating over the data set we cache the resultant files in `CACHE_DIR` for quick access. These can then be accessed using the globs defined earlier.

# %%
# The stopwords for the Dutch language. These come as downloadable sets with NLTK.
nltk.download('stopwords')
nltk.download('punkt')
dutch_stopwords = set(stopwords.words('dutch'))

# The stemming utility, also for the Dutch language.
dutch_stemmer = SnowballStemmer('dutch')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def tokens_of(text):
    text = " ".join(text.splitlines())  # remove line endings and make the file one, huge string,
    text = unidecode(text)              # boil Unicode back to ASCII, removing accents,
    text = text.lower().strip()         # lowercase everything
                                        # and use only ascii, three+ letter sequences as tokens/words/terms
    return re.split('[^a-zA-Z]+', text)

def stemmed_tokens(text, stemmer):
    return [stemmer.stem(token) for token in tokens_of(text)]

def cleaned_and_stemmed_text(from_file, text, stopwords, stemmer):
    text = ' '.join([token for token in stemmed_tokens(text, stemmer) if (token not in stopwords) and (len(token) > 2)])
    if len(text) < 2048:
        print(f"suspiciously small file {from_file} has only {len(text)} characters")
    return text

def extract_pdf(from_file, to_file, stopwords, stemmer):
    document = fitz.open(from_file)
    text = ""
    for page in document:
        text = text + " " + page.get_text('text')

    with open(to_file, WRITE) as f:
        text = cleaned_and_stemmed_text(from_file, text, stopwords, stemmer)
        f.write(text)
        f.write(' ')

def extract_msword(from_file, to_file, stopwords, stemmer):
    with open(to_file, WRITE) as f:
        text = str(textract.process(str(from_file)))
        text = cleaned_and_stemmed_text(from_file, text, stopwords, stemmer)
        f.write(text)

def encoding_of(file):
    rawdata = open(file, "rb").read()
    if len(rawdata) == 0:
        return 'ascii'
    encoding = chardet.detect(rawdata)['encoding']
    print(f"loading {file} using {encoding} encoding")
    return encoding

def extract_plain(from_file, to_file, stopwords, stemmer):
    text = from_file.read_text(encoding=encoding_of(from_file))
    if len(text) == 0:
        print(f"ignoring {from_file} as it is empty")
    else:
        with open(to_file, WRITE) as f:
            text = cleaned_and_stemmed_text(from_file, text, stopwords, stemmer)
            f.write(text)

# https://stackoverflow.com/questions/328356/extracting-text-from-html-file-using-python

def extract_html(from_file, to_file, stopwords, stemmer):
    text = from_file.read_text(encoding=encoding_of(from_file))
    if len(text) == 0:
        print(f"ignoring {from_file} as it is empty")
    else:
        with open(to_file, WRITE) as f:
            soup = BeautifulSoup(text, features="html.parser")
            # r=ip out script and style elements as these would pollute the text
            for script in soup(["script", "style"]):
                script.extract()
            text = soup.get_text()
            
            text = cleaned_and_stemmed_text(from_file, text, stopwords, stemmer)
            f.write(text)

def extract_file(from_file):
    mime_type = filetype.guess_mime(from_file)
    to_file = to_cache(from_file.with_suffix('.txt'))

    if to_file.exists():
        pass
    elif from_file.stem == 'GM1711OB02':
        print(f"ignoring {from_file} as it is of MIME type text/css")
    elif mime_type == "application/pdf":
        extract_pdf(from_file, to_file, dutch_stopwords, dutch_stemmer)
    elif mime_type == "application/vnd.openxmlformats-officedocument.wordprocessingml.document" or \
         mime_type == "application/msword":
        extract_msword(from_file, to_file, dutch_stopwords, dutch_stemmer)
    elif not mime_type:
        if from_file.suffix.lower() == '.txt':
            extract_plain(from_file, to_file, dutch_stopwords, dutch_stemmer)
        if from_file.suffix.lower() == '.zip':
            # seems wrong, but it is correct for our data...
            extract_html(from_file, to_file, dutch_stopwords, dutch_stemmer)
    else:
        raise Exception(f"don't known how to handle {from_file} of MIME type {mime_type}")

def extract_dir(glob):
     with Pool(multiprocessing.cpu_count() + 1) as p:
        p.map(extract_file, [file for file in expand_glob(glob)])

# %%
extract_dir(GLOB_RAW_DOCUMENTS)
# Out:
# suspiciously small file ../data/Governance/GM0040WS01.docx has only 12 characters
# suspiciously small file ../data/Governance/GM0202WS01.docx has only 10 characters
# suspiciously small file ../data/Governance/GM0005CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0173IK01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0081WS01.docx has only 18 characters
# suspiciously small file ../data/Governance/GM0140IK01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0085IK01.pdf has only 0 characters
# loading ../data/Governance/GM0007CA01.zip using ascii encoding
# suspiciously small file ../data/Governance/GM0007CA01.zip has only 95 characters
# suspiciously small file ../data/Governance/GM0269WS01.docx has only 13 characters
# suspiciously small file ../data/Governance/GM0269WS02.docx has only 42 characters
# suspiciously small file ../data/Governance/GM0007IK01.pdf has only 1996 characters
# suspiciously small file ../data/Governance/GM0173WS01.docx has only 12 characters
# suspiciously small file ../data/Governance/GM0173WS02.docx has only 20 characters
# suspiciously small file ../data/Governance/GM0056CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0243WS08.docx has only 43 characters
# suspiciously small file ../data/Governance/GM0275CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0244OB01.pdf has only 1691 characters
# suspiciously small file ../data/Governance/GM0147CA02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0147CA03.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0244OB04.pdf has only 1284 characters
# suspiciously small file ../data/Governance/GM0213OB01.pdf has only 1342 characters
# suspiciously small file ../data/Governance/GM0056WS01.docx has only 36 characters
# suspiciously small file ../data/Governance/GM0090WS01.docx has only 18 characters
# suspiciously small file ../data/Governance/GM0090WS02.docx has only 9 characters
# suspiciously small file ../data/Governance/GM0180OB01.pdf has only 853 characters
# suspiciously small file ../data/Governance/GM0180OB04.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0147OB01.docx has only 318 characters
# ignoring ../data/Governance/GM0147PB02.zip as it is empty
# suspiciously small file ../data/Governance/GM0147WS03.docx has only 67 characters
# suspiciously small file ../data/Governance/GM0277IK01.pdf has only 991 characterssuspiciously small file ../data/Governance/GM0148CA01.pdf has only 0 characters
#
# suspiciously small file ../data/Governance/GM0214CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0277PB01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0183PB01.docx has only 37 characters
# suspiciously small file ../data/Governance/GM0183WS01.docx has only 11 characters
# suspiciously small file ../data/Governance/GM0184EX01.docx has only 27 characters
# suspiciously small file ../data/Governance/GM0246OB01.pdf has only 396 characters
# suspiciously small file ../data/Governance/GM0148OB02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0281WS01.docx has only 8 characters
# suspiciously small file ../data/Governance/GM0014OB04.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0285WS02.docx has only 48 characters
# suspiciously small file ../data/Governance/GM0059OB01.pdf has only 447 characters
# suspiciously small file ../data/Governance/GM0216OB04.pdf has only 864 characters
# suspiciously small file ../data/Governance/GM0252OB01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0063JS01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0222IK01.pdf has only 1413 characters
# suspiciously small file ../data/Governance/GM0252WS01.docx has only 8 characters
# suspiciously small file ../data/Governance/GM0114WS01.docx has only 15 characters
# suspiciously small file ../data/Governance/GM0160DV01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0196OB02.pdf has only 1910 characters
# ignoring ../data/Governance/GM0225OB02.zip as it is empty
# suspiciously small file ../data/Governance/GM0202PB01.docx has only 17 characters
# suspiciously small file ../data/Governance/GM0296WS02.docx has only 135 characters
# suspiciously small file ../data/Governance/GM0297CA01.pdf has only 3 characters
# suspiciously small file ../data/Governance/GM0406WS01.docx has only 38 characters
# suspiciously small file ../data/Governance/GM0356EX01.docx has only 592 characters
# suspiciously small file ../data/Governance/GM0327CA01.pdf has only 0 characters
# ignoring ../data/Governance/GM0542CA01.zip as it is emptysuspiciously small file ../data/Governance/GM0356WS02.docx has only 196 characters
#
# suspiciously small file ../data/Governance/GM0451CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0542WS01.docx has only 82 characters
# suspiciously small file ../data/Governance/GM0416WS01.docx has only 21 characters
# suspiciously small file ../data/Governance/GM0417CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0302OB01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0393JS01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0420IK01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0420OB03.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0546IK01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0302TV01.pdf has only 0 characterssuspiciously small file ../data/Governance/GM0339JS01.pdf has only 0 characters
#
# suspiciously small file ../data/Governance/GM0302WS05.docx has only 550 characters
# suspiciously small file ../data/Governance/GM0518PB02.pdf has only 1104 characters
# suspiciously small file ../data/Governance/GM0363WS01.docx has only 13 characters
# suspiciously small file ../data/Governance/GM0370CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0437EX01.docx has only 1018 characters
# suspiciously small file ../data/Governance/GM0373DV01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0307WS03.docx has only 63 characters
# ignoring ../data/Governance/GM0439CA02.zip as it is empty
# ignoring ../data/Governance/GM0439CA03.zip as it is empty
# suspiciously small file ../data/Governance/GM0308EX01.docx has only 1566 characters
# suspiciously small file ../data/Governance/GM0375CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0399CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0399DV02.docx has only 62 characters
# loading ../data/Governance/GM0399JS01.zip using ascii encoding
# suspiciously small file ../data/Governance/GM0399JS01.zip has only 1111 characters
# loading ../data/Governance/GM0399PB02.zip using ascii encoding
# suspiciously small file ../data/Governance/GM0399PB02.zip has only 1144 characters
# suspiciously small file ../data/Governance/GM0310CA01.pdf has only 0 characters
# loading ../data/Governance/GM0399PB03.zip using ascii encoding
# suspiciously small file ../data/Governance/GM0399PB03.zip has only 1144 characters
# suspiciously small file ../data/Governance/GM0399TV01.docx has only 51 characters
# suspiciously small file ../data/Governance/GM0399WS02.docx has only 19 characters
# suspiciously small file ../data/Governance/GM0530WS01.docx has only 18 characters
# suspiciously small file ../data/Governance/GM0441DV01.pdf has only 0 characters
# loading ../data/Governance/GM0375JS01.txt using Windows-1252 encoding
# suspiciously small file ../data/Governance/GM0441DV02.pdf has only 0 characters
# loading ../data/Governance/GM0375PB01.zip using Windows-1252 encoding
# suspiciously small file ../data/Governance/GM0553WS05.docx has only 868 characters
# suspiciously small file ../data/Governance/GM0345EX02.docx has only 1528 characters
# suspiciously small file ../data/Governance/GM0448IK01.pdf has only 0 characters
# loading ../data/Governance/GM0375WS01.txt using Windows-1252 encoding
# suspiciously small file ../data/Governance/GM0345WS01.docx has only 13 characters
# suspiciously small file ../data/Governance/GM0345WS02.docx has only 23 characters
# suspiciously small file ../data/Governance/GM0402IK01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0448OB04.pdf has only 1180 characters
# suspiciously small file ../data/Governance/GM0569PB01.pdf has only 0 characters
# loading ../data/Governance/GM0313TV01.zip using ascii encoding
# suspiciously small file ../data/Governance/GM0313TV01.zip has only 206 characters
# suspiciously small file ../data/Governance/GM0617OB01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0321OB02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0579CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0579IK01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0353DV02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0537TV01.pdf has only 1372 characters
# suspiciously small file ../data/Governance/GM0622WS01.docx has only 40 characters
# suspiciously small file ../data/Governance/GM0584DV02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0824WS01.docx has only 14 characters
# suspiciously small file ../data/Governance/GM0748OB01.pdf has only 1513 characters
# suspiciously small file ../data/Governance/GM0603DV01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0603DV02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0503CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0826OB02.docx has only 89 characters
# suspiciously small file ../data/Governance/GM0627CA01.pdf has only 0 characterssuspiciously small file ../data/Governance/GM0753IK01.pdf has only 0 characters
#
# suspiciously small file ../data/Governance/GM0779WS01.docx has only 19 characters
# suspiciously small file ../data/Governance/GM0784DV01.docx has only 38 characters
# suspiciously small file ../data/Governance/GM0784OB01.docx has only 113 characters
# suspiciously small file ../data/Governance/GM0784PB01.docx has only 69 characters
# suspiciously small file ../data/Governance/GM0784WS01.docx has only 12 characters
# suspiciously small file ../data/Governance/GM0785CA02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0785OB01.docx has only 87 characters
# suspiciously small file ../data/Governance/GM0785PB01.docx has only 78 characters
# suspiciously small file ../data/Governance/GM0785TV01.docx has only 82 characters
# suspiciously small file ../data/Governance/GM0785WS01.docx has only 9 characters
# suspiciously small file ../data/Governance/GM0861OB04.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0826WS04.docx has only 65 characters
# suspiciously small file ../data/Governance/GM0844CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0844OB02.pdf has only 52 characters
# suspiciously small file ../data/Governance/GM0844WS01.docx has only 13 characters
# suspiciously small file ../data/Governance/GM0606WS06.docx has only 21 characters
# suspiciously small file ../data/Governance/GM0888WS01.docx has only 15 characters
# suspiciously small file ../data/Governance/GM0715IK01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0611WS01.docx has only 10 characters
# suspiciously small file ../data/Governance/GM0613CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0715WS01.docx has only 11 characters
# suspiciously small file ../data/Governance/GM0889WS01.docx has only 10 characters
# suspiciously small file ../data/Governance/GM0867WS01.docx has only 12 characters
# ignoring ../data/Governance/GM0613OB02.zip as it is empty
# suspiciously small file ../data/Governance/GM0613TV01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0614CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0796WS01.docx has only 17 characters
# suspiciously small file ../data/Governance/GM0614OB02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0798DV01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0893WS01.docx has only 8 characters
# suspiciously small file ../data/Governance/GM0638IK01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0809PB01.docx has only 83 characters
# suspiciously small file ../data/Governance/GM0809TV01.docx has only 79 characters
# suspiciously small file ../data/Governance/GM0809WS01.docx has only 14 characters
# suspiciously small file ../data/Governance/GM0846WS01.docx has only 17 characters
# suspiciously small file ../data/Governance/GM0762CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0873TV01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0899WS01.docx has only 12 characters
# suspiciously small file ../data/Governance/GM0874IK01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0765WS01.docx has only 10 characters
# loading ../data/Governance/GM0917IK01.zip using utf-8 encoding
# loading ../data/Governance/GM0766CA01.zip using utf-8 encoding
# suspiciously small file ../data/Governance/GM0766IK01.docx has only 59 characters
# suspiciously small file ../data/Governance/GM0823CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0766WS01.docx has only 8 characters
# suspiciously small file ../data/Governance/GM0917WS01.docx has only 9 characters
# suspiciously small file ../data/Governance/GM0879JS01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0737WS01.docx has only 8 characters
# suspiciously small file ../data/Governance/GM0935CA01.docx has only 77 characters
# suspiciously small file ../data/Governance/GM0935OB01.docx has only 101 characters
# suspiciously small file ../data/Governance/GM0935OB02.docx has only 97 characters
# suspiciously small file ../data/Governance/GM0935PB01.docx has only 96 characters
# suspiciously small file ../data/Governance/GM0935TV01.docx has only 99 characters
# suspiciously small file ../data/Governance/GM0935WS01.docx has only 22 characters
# suspiciously small file ../data/Governance/GM0962WS01.docx has only 10 characters
# suspiciously small file ../data/Governance/GM0743CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0743IK01.pdf has only 1771 characters
# ignoring ../data/Governance/GM0772IK02.zip as it is empty
# suspiciously small file ../data/Governance/GM0944CA02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0944OB01.docx has only 86 characters
# suspiciously small file ../data/Governance/GM0944PB01.docx has only 75 characters
# suspiciously small file ../data/Governance/GM0944WS01.docx has only 18 characters
# suspiciously small file ../data/Governance/GM0777OB01.docx has only 289 characters
# suspiciously small file ../data/Governance/GM0777PB01.docx has only 83 characters
# suspiciously small file ../data/Governance/GM0777TV02.docx has only 271 characters
# suspiciously small file ../data/Governance/GM0777WS01.docx has only 8 characters
# suspiciously small file ../data/Governance/GM1655WS02.docx has only 41 characters
# loading ../data/Governance/GM0882OB01.zip using utf-8 encoding
# suspiciously small file ../data/Governance/GM0951CA01.docx has only 93 characters
# suspiciously small file ../data/Governance/GM0951IK01.docx has only 59 characters
# suspiciously small file ../data/Governance/GM0951JS01.docx has only 54 characters
# suspiciously small file ../data/Governance/GM0951PB01.docx has only 83 characters
# suspiciously small file ../data/Governance/GM0951TV01.docx has only 62 characters
# suspiciously small file ../data/Governance/GM0951WS01.docx has only 8 characters
# suspiciously small file ../data/Governance/GM0951WS02.docx has only 16 characters
# suspiciously small file ../data/Governance/GM1659CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1711CA01.pdf has only 0 characters
# ignoring ../data/Governance/GM1711OB02.txt as it is of MIME type text/css
# suspiciously small file ../data/Governance/GM1525TV02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1525WS03.docx has only 50 characters
# suspiciously small file ../data/Governance/GM1735PB01.docx has only 128 characters
# suspiciously small file ../data/Governance/GM1735TV01.docx has only 91 characters
# suspiciously small file ../data/Governance/GM1735WS01.docx has only 15 characters
# suspiciously small file ../data/Governance/GM1581EX01.pdf has only 1735 characters
# suspiciously small file ../data/Governance/GM1663WS01.docx has only 10 characters
# suspiciously small file ../data/Governance/GM1663WS02.docx has only 10 characters
# suspiciously small file ../data/Governance/GM1667JS01.docx has only 69 characters
# suspiciously small file ../data/Governance/GM1667OB02.docx has only 89 characters
# suspiciously small file ../data/Governance/GM1581WS01.docx has only 13 characters
# suspiciously small file ../data/Governance/GM0981PB01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1742WS01.docx has only 14 characters
# suspiciously small file ../data/Governance/GM1667WS01.docx has only 17 characters
# suspiciously small file ../data/Governance/GM0858OB01.pdf has only 1899 characters
# suspiciously small file ../data/Governance/GM1586WS01.docx has only 12 characters
# suspiciously small file ../data/Governance/GM1669OB03.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1621CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1891OB01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1891OB02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1674EX01.docx has only 44 characters
# suspiciously small file ../data/Governance/GM1719JS01.pdf has only 1098 characters
# suspiciously small file ../data/Governance/GM1699OB02.docx has only 48 characterssuspiciously small file ../data/Governance/GM1891TV01.pdf has only 0 characters
#
# suspiciously small file ../data/Governance/GM1774PB01.docx has only 40 characters
# suspiciously small file ../data/Governance/GM1774WS01.docx has only 14 characters
# suspiciously small file ../data/Governance/GM1674PB01.docx has only 48 characters
# suspiciously small file ../data/Governance/GM1674WS01.docx has only 13 characters
# suspiciously small file ../data/Governance/GM0860WS01.docx has only 10 characters
# ignoring ../data/Governance/GM1916TV02.zip as it is empty
# suspiciously small file ../data/Governance/GM1924CA01.docx has only 50 characters
# suspiciously small file ../data/Governance/GM1924EX01.docx has only 114 characters
# suspiciously small file ../data/Governance/GM1640DV01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1924JS01.docx has only 82 characters
# suspiciously small file ../data/Governance/GM1924OB02.docx has only 77 characters
# suspiciously small file ../data/Governance/GM1640JS01.docx has only 64 characterssuspiciously small file ../data/Governance/GM1924PB01.docx has only 76 characters
#
# suspiciously small file ../data/Governance/GM1924WS01.docx has only 23 characters
# suspiciously small file ../data/Governance/GM1640PB01.docx has only 57 characters
# suspiciously small file ../data/Governance/GM1640WS01.docx has only 10 characters
# suspiciously small file ../data/Governance/GM0984TV02.docx has only 110 characters
# suspiciously small file ../data/Governance/GM0984WS01.docx has only 10 characters
# suspiciously small file ../data/Governance/GM1700WS01.docx has only 14 characters
# ignoring ../data/Governance/GM1680DV01.zip as it is empty
# suspiciously small file ../data/Governance/GM1680DV02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1680IK01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1927CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1783WS01.docx has only 20 characters
# suspiciously small file ../data/Governance/GM1842OB02.pdf has only 1300 characters
# suspiciously small file ../data/Governance/GM1722OB02.pdf has only 0 characters
# loading ../data/Governance/GM1859IK01.zip using utf-8 encoding
# suspiciously small file ../data/Governance/GM1931CA01.docx has only 58 characters
# suspiciously small file ../data/Governance/GM1931CA02.docx has only 59 characters
# suspiciously small file ../data/Governance/GM1931PB01.docx has only 54 characters
# suspiciously small file ../data/Governance/GM1931WS01.docx has only 18 characters
# suspiciously small file ../data/Governance/GM1655OB02.docx has only 33 characters
# suspiciously small file ../data/Governance/GM1655PB01.docx has only 33 characters
# suspiciously small file ../data/Governance/GM1655TV01.docx has only 33 characters
# suspiciously small file ../data/Governance/GM1655WS01.docx has only 14 characters
# suspiciously small file ../data/Governance/GM1940EX01.docx has only 48 characters
# suspiciously small file ../data/Governance/GM1940OB01.pdf has only 102 characters
# suspiciously small file ../data/Governance/GM1896OB01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0994CA01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1945TV01.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1945WS01.docx has only 13 characters
# suspiciously small file ../data/Governance/GM0994TV02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM0995PB01.docx has only 56 characters
# suspiciously small file ../data/Governance/GM1685CA01.docx has only 51 characters
# suspiciously small file ../data/Governance/GM1883WS01.docx has only 17 characters
# suspiciously small file ../data/Governance/GM0995WS01.docx has only 12 characters
# suspiciously small file ../data/Governance/GM1685OB02.docx has only 84 characters
# suspiciously small file ../data/Governance/GM1987CA02.pdf has only 0 characters
# suspiciously small file ../data/Governance/GM1685PB01.docx has only 86 characters
# suspiciously small file ../data/Governance/GM1685WS01.docx has only 11 characters
# suspiciously small file ../data/Governance/GM1730WS01.docx has only 12 characters
# suspiciously small file ../data/Governance/GM1903DV02.docx has only 85 characters
# suspiciously small file ../data/Governance/GM1903DV03.docx has only 77 characters
# suspiciously small file ../data/Governance/GM1903TV01.pdf has only 1559 characters
# suspiciously small file ../data/Governance/GM1903WS01.docx has only 17 characters
# suspiciously small file ../data/Governance/GM1734WS01.docx has only 13 characters
# suspiciously small file ../data/Governance/GM1735DV01.docx has only 96 characters
# loading ../data/Governance/GM1735IK01.txt using ascii encoding
# suspiciously small file ../data/Governance/GM1735IK01.txt has only 93 characters
# loading ../data/Governance/GM1735OB01.txt using ascii encoding
# suspiciously small file ../data/Governance/GM1735OB01.txt has only 126 characters
# suspiciously small file ../data/Governance/GM1908JS01.docx has only 100 characters
# suspiciously small file ../data/Governance/GM1908PB01.docx has only 97 characters
# suspiciously small file ../data/Governance/GM1908WS01.docx has only 16 characters

# %% [markdown]
# ### Deduplication
# The data set was assembled by a group of people answering a questionnaire and uploading document supporting their arguments in the process. Sometimes they would upload the same document to answer more than one question on the questionnaire, so we have a few duplicate files. Here we identify duplicates by checksum and remove their cached text documents.

# %%
# https://stackoverflow.com/questions/3431825/generating-an-md5-checksum-of-a-file

def md5(file):
    hash_md5 = hashlib.md5()
    with open(file, READ_BINARY) as f:
        for chunk in iter(lambda: f.read(4096), b""):
            hash_md5.update(chunk)
    return hash_md5.hexdigest()

def delete_duplicates(glob):
    hashes = set()
    dupes = 0
    for file in expand_glob(glob):
        hash = md5(file)
        if hash in hashes:
            print(f"deleting {file} as dupe")
            file.unlink()
            dupes += 1
        else:
            hashes.add(hash)
    print(f"deleted {dupes} duplicates")

# %%
delete_duplicates(GLOB_ALL_DOCUMENTS)
# Out:
# deleting ../cache/Governance/GM0014OB04.txt as dupe
# deleting ../cache/Governance/GM0056CA01.txt as dupe
# deleting ../cache/Governance/GM0059IK01.txt as dupe
# deleting ../cache/Governance/GM0063CA02.txt as dupe
# deleting ../cache/Governance/GM0063CA03.txt as dupe
# deleting ../cache/Governance/GM0063JS01.txt as dupe
# deleting ../cache/Governance/GM0079EX01.txt as dupe
# deleting ../cache/Governance/GM0079IK01.txt as dupe
# deleting ../cache/Governance/GM0085IK01.txt as dupe
# deleting ../cache/Governance/GM0086CA02.txt as dupe
# deleting ../cache/Governance/GM0093DV01.txt as dupe
# deleting ../cache/Governance/GM0140IK01.txt as dupe
# deleting ../cache/Governance/GM0147CA02.txt as dupe
# deleting ../cache/Governance/GM0147CA03.txt as dupe
# deleting ../cache/Governance/GM0148CA01.txt as dupe
# deleting ../cache/Governance/GM0148DV02.txt as dupe
# deleting ../cache/Governance/GM0148OB02.txt as dupe
# deleting ../cache/Governance/GM0160DV01.txt as dupe
# deleting ../cache/Governance/GM0168DV02.txt as dupe
# deleting ../cache/Governance/GM0173IK01.txt as dupe
# deleting ../cache/Governance/GM0180OB04.txt as dupe
# deleting ../cache/Governance/GM0214CA01.txt as dupe
# deleting ../cache/Governance/GM0225CA01.txt as dupe
# deleting ../cache/Governance/GM0225JS01.txt as dupe
# deleting ../cache/Governance/GM0226IK02.txt as dupe
# deleting ../cache/Governance/GM0232CA02.txt as dupe
# deleting ../cache/Governance/GM0246IK01.txt as dupe
# deleting ../cache/Governance/GM0252OB01.txt as dupe
# deleting ../cache/Governance/GM0267PB02.txt as dupe
# deleting ../cache/Governance/GM0275CA01.txt as dupe
# deleting ../cache/Governance/GM0277OB03.txt as dupe
# deleting ../cache/Governance/GM0277PB01.txt as dupe
# deleting ../cache/Governance/GM0293IK01.txt as dupe
# deleting ../cache/Governance/GM0294CA02.txt as dupe
# deleting ../cache/Governance/GM0297OB01.txt as dupe
# deleting ../cache/Governance/GM0302OB01.txt as dupe
# deleting ../cache/Governance/GM0302TV01.txt as dupe
# deleting ../cache/Governance/GM0310CA01.txt as dupe
# deleting ../cache/Governance/GM0321OB02.txt as dupe
# deleting ../cache/Governance/GM0327CA01.txt as dupe
# deleting ../cache/Governance/GM0327DV02.txt as dupe
# deleting ../cache/Governance/GM0327DV03.txt as dupe
# deleting ../cache/Governance/GM0339JS01.txt as dupe
# deleting ../cache/Governance/GM0353CA03.txt as dupe
# deleting ../cache/Governance/GM0353DV02.txt as dupe
# deleting ../cache/Governance/GM0361DV02.txt as dupe
# deleting ../cache/Governance/GM0361TV01.txt as dupe
# deleting ../cache/Governance/GM0362IK01.txt as dupe
# deleting ../cache/Governance/GM0370CA01.txt as dupe
# deleting ../cache/Governance/GM0373DV01.txt as dupe
# deleting ../cache/Governance/GM0375CA01.txt as dupe
# deleting ../cache/Governance/GM0393JS01.txt as dupe
# deleting ../cache/Governance/GM0399CA01.txt as dupe
# deleting ../cache/Governance/GM0399PB03.txt as dupe
# deleting ../cache/Governance/GM0402IK01.txt as dupe
# deleting ../cache/Governance/GM0406IK02.txt as dupe
# deleting ../cache/Governance/GM0417CA01.txt as dupe
# deleting ../cache/Governance/GM0420IK01.txt as dupe
# deleting ../cache/Governance/GM0420OB03.txt as dupe
# deleting ../cache/Governance/GM0432CA01.txt as dupe
# deleting ../cache/Governance/GM0441DV01.txt as dupe
# deleting ../cache/Governance/GM0441DV02.txt as dupe
# deleting ../cache/Governance/GM0448IK01.txt as dupe
# deleting ../cache/Governance/GM0451CA01.txt as dupe
# deleting ../cache/Governance/GM0498IK01.txt as dupe
# deleting ../cache/Governance/GM0503CA01.txt as dupe
# deleting ../cache/Governance/GM0505IK01.txt as dupe
# deleting ../cache/Governance/GM0531IK01.txt as dupe
# deleting ../cache/Governance/GM0532PB02.txt as dupe
# deleting ../cache/Governance/GM0545OB02.txt as dupe
# deleting ../cache/Governance/GM0545TV02.txt as dupe
# deleting ../cache/Governance/GM0546IK01.txt as dupe
# deleting ../cache/Governance/GM0569PB01.txt as dupe
# deleting ../cache/Governance/GM0576EX01.txt as dupe
# deleting ../cache/Governance/GM0579CA01.txt as dupe
# deleting ../cache/Governance/GM0579IK01.txt as dupe
# deleting ../cache/Governance/GM0584DV02.txt as dupe
# deleting ../cache/Governance/GM0590IK01.txt as dupe
# deleting ../cache/Governance/GM0603DV01.txt as dupe
# deleting ../cache/Governance/GM0603DV02.txt as dupe
# deleting ../cache/Governance/GM0606OB02.txt as dupe
# deleting ../cache/Governance/GM0610IK01.txt as dupe
# deleting ../cache/Governance/GM0611WS01.txt as dupe
# deleting ../cache/Governance/GM0613CA01.txt as dupe
# deleting ../cache/Governance/GM0613TV01.txt as dupe
# deleting ../cache/Governance/GM0614CA01.txt as dupe
# deleting ../cache/Governance/GM0614OB02.txt as dupe
# deleting ../cache/Governance/GM0617OB01.txt as dupe
# deleting ../cache/Governance/GM0627CA01.txt as dupe
# deleting ../cache/Governance/GM0638IK01.txt as dupe
# deleting ../cache/Governance/GM0642IK01.txt as dupe
# deleting ../cache/Governance/GM0715IK01.txt as dupe
# deleting ../cache/Governance/GM0737DV01.txt as dupe
# deleting ../cache/Governance/GM0737IK01.txt as dupe
# deleting ../cache/Governance/GM0743CA01.txt as dupe
# deleting ../cache/Governance/GM0753IK01.txt as dupe
# deleting ../cache/Governance/GM0762CA01.txt as dupe
# deleting ../cache/Governance/GM0785CA02.txt as dupe
# deleting ../cache/Governance/GM0785CA03.txt as dupe
# deleting ../cache/Governance/GM0798DV01.txt as dupe
# deleting ../cache/Governance/GM0815PB02.txt as dupe
# deleting ../cache/Governance/GM0823CA01.txt as dupe
# deleting ../cache/Governance/GM0844CA01.txt as dupe
# deleting ../cache/Governance/GM0861OB04.txt as dupe
# deleting ../cache/Governance/GM0873TV01.txt as dupe
# deleting ../cache/Governance/GM0874IK01.txt as dupe
# deleting ../cache/Governance/GM0879JS01.txt as dupe
# deleting ../cache/Governance/GM0944CA02.txt as dupe
# deleting ../cache/Governance/GM0981PB01.txt as dupe
# deleting ../cache/Governance/GM0984DV01.txt as dupe
# deleting ../cache/Governance/GM0988IK01.txt as dupe
# deleting ../cache/Governance/GM0994CA01.txt as dupe
# deleting ../cache/Governance/GM0994OB01.txt as dupe
# deleting ../cache/Governance/GM0994TV02.txt as dupe
# deleting ../cache/Governance/GM1525OB01.txt as dupe
# deleting ../cache/Governance/GM1525TV02.txt as dupe
# deleting ../cache/Governance/GM1621CA01.txt as dupe
# deleting ../cache/Governance/GM1640DV01.txt as dupe
# deleting ../cache/Governance/GM1655PB01.txt as dupe
# deleting ../cache/Governance/GM1655TV01.txt as dupe
# deleting ../cache/Governance/GM1659CA01.txt as dupe
# deleting ../cache/Governance/GM1663WS02.txt as dupe
# deleting ../cache/Governance/GM1669OB03.txt as dupe
# deleting ../cache/Governance/GM1680DV02.txt as dupe
# deleting ../cache/Governance/GM1680IK01.txt as dupe
# deleting ../cache/Governance/GM1684IK01.txt as dupe
# deleting ../cache/Governance/GM1684TV01.txt as dupe
# deleting ../cache/Governance/GM1702IK01.txt as dupe
# deleting ../cache/Governance/GM1711CA01.txt as dupe
# deleting ../cache/Governance/GM1722DV01.txt as dupe
# deleting ../cache/Governance/GM1722IK01.txt as dupe
# deleting ../cache/Governance/GM1722OB02.txt as dupe
# deleting ../cache/Governance/GM1730PB02.txt as dupe
# deleting ../cache/Governance/GM1884OB06.txt as dupe
# deleting ../cache/Governance/GM1891DV01.txt as dupe
# deleting ../cache/Governance/GM1891IK01.txt as dupe
# deleting ../cache/Governance/GM1891OB01.txt as dupe
# deleting ../cache/Governance/GM1891OB02.txt as dupe
# deleting ../cache/Governance/GM1891TV01.txt as dupe
# deleting ../cache/Governance/GM1896OB01.txt as dupe
# deleting ../cache/Governance/GM1904PB01.txt as dupe
# deleting ../cache/Governance/GM1927CA01.txt as dupe
# deleting ../cache/Governance/GM1945TV01.txt as dupe
# deleting ../cache/Governance/GM1987CA02.txt as dupe
# deleted 144 duplicates

# %% [markdown]
# ---
# ## Generate Word Clouds
# We now go through the text documents again, and generate a word cloud image for each file. There are too many to show word clouds for individual files, so we don't try. We do generate and show the word clouds for a few of the collections of documents.

# %%
def make_one_file_cloud(file):
    try:
        cloud = WordCloud(background_color="white", max_words=20).generate(file.read_text())
        cloud.to_file(file.with_suffix('.png'))
    except ValueError as e:
        print(f"cannot generate word cloud for {file}: {e}")

def make_per_file_cloud(glob):
    with Pool(multiprocessing.cpu_count() + 1) as p:
        p.map(make_one_file_cloud, [file for file in expand_glob(glob)])

# %%
make_per_file_cloud(GLOB_ALL_DOCUMENTS)
# Out:
# cannot generate word cloud for ../cache/Governance/GM0005CA01.txt: We need at least 1 word to plot a word cloud, got 0.

# %%
def make_word_cloud(glob):
    corpus = ""
    for file in expand_glob(glob):
        corpus = corpus + " " + file.read_text()

    cloud = WordCloud(background_color="white", max_words=50).generate(corpus)
    plt.axis('off')
    plt.imshow(cloud);

# %%
make_word_cloud(GLOB_ALL_DOCUMENTS)

# %%
make_word_cloud(GLOB_CA)

# %%
make_word_cloud(GLOB_DV)

# %%
make_word_cloud(GLOB_EX)

# %%
make_word_cloud(GLOB_IK)

# %%
make_word_cloud(GLOB_JS)

# %%
make_word_cloud(GLOB_OB)

# %%
make_word_cloud(GLOB_PB)

# %%
make_word_cloud(GLOB_TV)

# %%
make_word_cloud(GLOB_WS)

# %% [markdown]
# ---
# ## Document Type and File Type Counts
# Here we count and graph the doucment types and file types, just to add some colour to the document set.

# %%
def count_dir(glob):
    mime_types = []
    extensions = []
    docu_types = []

    for from_file in expand_glob(glob):
        mime_type = filetype.guess_mime(from_file)
        if from_file.stem == 'GM1711OB02':
            mime_types.append("text/css")
        elif not mime_type:
            if from_file.suffix.lower() == '.txt':
                mime_types.append("text/plain")
            elif from_file.suffix.lower() == '.zip':
                # seems wrong, but it is correct for our data...
                mime_types.append("text/html")
            else:
                raise Exception(f"don't known how to handle {from_file} of MIME type {mime_type}")
        else:
            mime_types.append(mime_type)
            
        extensions.append(from_file.suffix.lower())
        docu_types.append(from_file.stem[6:8])

    return pd.DataFrame.from_records(list(dict(Counter(mime_types)).items())).set_index(0), \
           pd.DataFrame.from_records(list(dict(Counter(extensions)).items())).set_index(0), \
           pd.DataFrame.from_records(list(dict(Counter(docu_types)).items())).set_index(0)

# %%
mime_types, extensions, docu_types = count_dir(GLOB_RAW_DOCUMENTS)

mime_types.sort_values(by=1).plot.barh();

# %%
docu_types.sort_values(by=1).plot.barh();

# %%
extensions.sort_values(by=1).plot.barh();
